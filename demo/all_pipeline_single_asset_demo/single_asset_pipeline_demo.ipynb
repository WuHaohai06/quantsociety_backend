# %% [markdown]
# # Single Asset Pipeline Demo
#
# This notebook runs the single-asset end-to-end demo and inspects the generated factor, position, and backtest artifacts under workspace_data.

# %%
from pathlib import Path

import sys



import matplotlib.pyplot as plt

import pandas as pd

from IPython.display import display



REPO_ROOT = Path.cwd().resolve()

DEMO_DIR = REPO_ROOT / "demo" / "all_pipeline_single_asset_demo"

if str(DEMO_DIR) not in sys.path:

    sys.path.insert(0, str(DEMO_DIR))



from run_single_asset_pipeline_demo import load_demo_artifacts, run_demo



plt.style.use("seaborn-v0_8-whitegrid")

pd.set_option("display.max_columns", 20)

pd.set_option("display.width", 160)

# %%
summary = run_demo(force=True)
artifacts = load_demo_artifacts(summary)

summary_view = pd.DataFrame(
    [
        {"metric": "trade_days", "value": summary["inputs"]["trade_days"]},
        {"metric": "final_equity", "value": summary["backtest"]["summary"]["final_equity"]},
        {"metric": "total_return", "value": summary["backtest"]["metrics"]["total_return"]},
        {"metric": "annual_return", "value": summary["backtest"]["metrics"]["annual_return"]},
        {"metric": "sharpe", "value": summary["backtest"]["metrics"]["sharpe"]},
    ]
)
display(summary_view)
summary["paths"]
# Out:
# 2026-04-05 19:38:44 | INFO    | factor_engine.runtime.engine | 开始从配置物化因子: /home/yluel/share/projects/quantsociety_backend_project/workspace_data/demos/single_asset_pipeline_demo/configs/factor_engine/single_asset_mom_3_v1.yaml
# 2026-04-05 19:38:44 | INFO    | factor_engine.runtime.engine | 加载配置文件: /home/yluel/share/projects/quantsociety_backend_project/workspace_data/demos/single_asset_pipeline_demo/configs/factor_engine/single_asset_mom_3_v1.yaml
# 2026-04-05 19:38:44 | INFO    | factor_engine.runtime.engine | 配置加载完成: factor=close_mom_3, backend=PandasBackend, data_source=KlineParquetSource, cache=on
# 2026-04-05 19:38:44 | INFO    | factor_engine.runtime.engine | 开始落盘因子 'close_mom_3'
# 2026-04-05 19:38:44 | INFO    | factor_engine.runtime.engine | 开始执行因子 'close_mom_3'
# 2026-04-05 19:38:44 | INFO    | factor_engine.runtime.engine | 开始编译因子 'close_mom_3'
# 2026-04-05 19:38:44 | INFO    | factor_engine.runtime.engine | 完成编译因子 'close_mom_3'，lookback=3，耗时 0.00s
# 2026-04-05 19:38:44 | INFO    | factor_engine.runtime.engine | 完成执行因子 'close_mom_3'，结果行数=90，非空=87，耗时 0.15s
# 2026-04-05 19:38:44 | INFO    | factor_engine.storage.materializer | 落盘因子 single_asset_mom_3_v1 [--------------------] 0/1 partition (0.0%, 0.00s)
# 2026-04-05 19:38:44 | INFO    | factor_engine.storage.materializer | 分区写入完成: factor_dir=/home/yluel/share/projects/quantsociety_backend_project/workspace_data/factors/lake/factors/single_asset_mom_3_v1, year=2024, existing_rows=0, incoming_rows=87, final_rows=87
# 2026-04-05 19:38:44 | INFO    | factor_engine.storage.materializer | 落盘因子 single_asset_mom_3_v1 [####################] 1/1 partition (100.0%, 0.01s) - year=2024, rows=87
# 2026-04-05 19:38:44 | INFO    | factor_engine.storage.materializer | 因子 'single_asset_mom_3_v1' 落盘完成：87 行，分区 [2024]，水位线 [2024-01-05T00:00:00 → 2024-05-06T00:00:00]
# 2026-04-05 19:38:44 | INFO    | factor_engine.runtime.engine | 完成落盘因子 'close_mom_3'，factor_id=single_asset_mom_3_v1，rows_written=87
# 2026-04-05 19:38:44 | INFO    | factor_engine.runtime.engine | 完成从配置物化因子: close_mom_3
# 2026-04-05 19:38:44 | INFO    | factor_engine.runtime.engine | 开始从配置物化因子: /home/yluel/share/projects/quantsociety_backend_project/workspace_data/demos/single_asset_pipeline_demo/configs/factor_engine/single_asset_gap_5_v1.yaml
# 2026-04-05 19:38:44 | INFO    | factor_engine.runtime.engine | 加载配置文件: /home/yluel/share/projects/quantsociety_backend_project/workspace_data/demos/single_asset_pipeline_demo/configs/factor_engine/single_asset_gap_5_v1.yaml
# 2026-04-05 19:38:44 | INFO    | factor_engine.runtime.engine | 配置加载完成: factor=close_gap_5, backend=PandasBackend, data_source=KlineParquetSource, cache=on
# 2026-04-05 19:38:44 | INFO    | factor_engine.runtime.engine | 开始落盘因子 'close_gap_5'
# 2026-04-05 19:38:44 | INFO    | factor_engine.runtime.engine | 开始执行因子 'close_gap_5'
# 2026-04-05 19:38:44 | INFO    | factor_engine.runtime.engine | 开始编译因子 'close_gap_5'
# 2026-04-05 19:38:44 | INFO    | factor_engine.runtime.engine | 完成编译因子 'close_gap_5'，lookback=5，耗时 0.00s
# 2026-04-05 19:38:44 | INFO    | factor_engine.runtime.engine | 完成执行因子 'close_gap_5'，结果行数=90，非空=86，耗时 0.16s
# 2026-04-05 19:38:44 | INFO    | factor_engine.storage.materializer | 落盘因子 single_asset_gap_5_v1 [--------------------] 0/1 partition (0.0%, 0.00s)
# 2026-04-05 19:38:44 | INFO    | factor_engine.storage.materializer | 分区写入完成: factor_dir=/home/yluel/share/projects/quantsociety_backend_project/workspace_data/factors/lake/factors/single_asset_gap_5_v1, year=2024, existing_rows=0, incoming_rows=86, final_rows=86
# 2026-04-05 19:38:44 | INFO    | factor_engine.storage.materializer | 落盘因子 single_asset_gap_5_v1 [####################] 1/1 partition (100.0%, 0.00s) - year=2024, rows=86
# 2026-04-05 19:38:44 | INFO    | factor_engine.storage.materializer | 因子 'single_asset_gap_5_v1' 落盘完成：86 行，分区 [2024]，水位线 [2024-01-08T00:00:00 → 2024-05-06T00:00:00]
# 2026-04-05 19:38:44 | INFO    | factor_engine.runtime.engine | 完成落盘因子 'close_gap_5'，factor_id=single_asset_gap_5_v1，rows_written=86
# 2026-04-05 19:38:44 | INFO    | factor_engine.runtime.engine | 完成从配置物化因子: close_gap_5
# 2026-04-05 19:38:44 | INFO    | factor_engine.runtime.engine | 开始从配置物化因子: /home/yluel/share/projects/quantsociety_backend_project/workspace_data/demos/single_asset_pipeline_demo/configs/factor_engine/single_asset_vol_delta_2_v1.yaml
# 2026-04-05 19:38:44 | INFO    | factor_engine.runtime.engine | 加载配置文件: /home/yluel/share/projects/quantsociety_backend_project/workspace_data/demos/single_asset_pipeline_demo/configs/factor_engine/single_asset_vol_delta_2_v1.yaml
# 2026-04-05 19:38:44 | INFO    | factor_engine.runtime.engine | 配置加载完成: factor=volume_delta_2, backend=PandasBackend, data_source=KlineParquetSource, cache=on
# 2026-04-05 19:38:44 | INFO    | factor_engine.runtime.engine | 开始落盘因子 'volume_delta_2'
# 2026-04-05 19:38:44 | INFO    | factor_engine.runtime.engine | 开始执行因子 'volume_delta_2'
# 2026-04-05 19:38:44 | INFO    | factor_engine.runtime.engine | 开始编译因子 'volume_delta_2'
# 2026-04-05 19:38:44 | INFO    | factor_engine.runtime.engine | 完成编译因子 'volume_delta_2'，lookback=3，耗时 0.00s
# 2026-04-05 19:38:45 | INFO    | factor_engine.runtime.engine | 完成执行因子 'volume_delta_2'，结果行数=90，非空=88，耗时 0.14s
# 2026-04-05 19:38:45 | INFO    | factor_engine.storage.materializer | 落盘因子 single_asset_vol_delta_2_v1 [--------------------] 0/1 partition (0.0%, 0.00s)
# 2026-04-05 19:38:45 | INFO    | factor_engine.storage.materializer | 分区写入完成: factor_dir=/home/yluel/share/projects/quantsociety_backend_project/workspace_data/factors/lake/factors/single_asset_vol_delta_2_v1, year=2024, existing_rows=0, incoming_rows=88, final_rows=88
# 2026-04-05 19:38:45 | INFO    | factor_engine.storage.materializer | 落盘因子 single_asset_vol_delta_2_v1 [####################] 1/1 partition (100.0%, 0.00s) - year=2024, rows=88
# 2026-04-05 19:38:45 | INFO    | factor_engine.storage.materializer | 因子 'single_asset_vol_delta_2_v1' 落盘完成：88 行，分区 [2024]，水位线 [2024-01-04T00:00:00 → 2024-05-06T00:00:00]
# 2026-04-05 19:38:45 | INFO    | factor_engine.runtime.engine | 完成落盘因子 'volume_delta_2'，factor_id=single_asset_vol_delta_2_v1，rows_written=88
# 2026-04-05 19:38:45 | INFO    | factor_engine.runtime.engine | 完成从配置物化因子: volume_delta_2
# 2026-04-05 19:38:45 | INFO    | single_asset_alpha.pipeline | ═══ 策略流水线启动 [SINGLE_DEMO] ═══
# 2026-04-05 19:38:45 | INFO    | single_asset_alpha.pipeline | 信号生成器: FactorThresholdSignal(name='FactorThreshold', params={'factor_names': ['mom_3', 'gap_5', 'vol_delta_2'], 'factor_weights': {'mom_3': 0.45, 'gap_5': 0.4, 'vol_delta_2': 0.15}, 'normalize': True, 'zscore_window': 12})
# 2026-04-05 19:38:45 | INFO    | single_asset_alpha.pipeline | 仓位映射器: ThresholdPositionMapper(name='ThresholdMapper', params={'long_entry_threshold': 0.18, 'long_exit_threshold': -0.04, 'short_entry_threshold': -0.18, 'short_exit_threshold': 0.04, 'allow_short': False, 'position_size': 0.99, 'shift_bars': 1})
# 2026-04-05 19:38:45 | INFO    | single_asset_alpha.pipeline | Step 1/5: 使用外部提供的行情数据
# 2026-04-05 19:38:45 | INFO    | single_asset_alpha.pipeline |   行情数据: 90 行, 时间范围: [2024-01-02 00:00:00 ~ 2024-05-06 00:00:00]
# 2026-04-05 19:38:45 | INFO    | single_asset_alpha.pipeline | Step 2/5: 生成择时信号 (C-1)...
# 2026-04-05 19:38:45 | INFO    | single_asset_alpha.pipeline |   信号统计: mean=0.0106, std=0.7413, NaN=9
# 2026-04-05 19:38:45 | INFO    | single_asset_alpha.pipeline | Step 3/5: 信号转目标仓位 (C-2)...
# 2026-04-05 19:38:45 | INFO    | single_asset_alpha.pipeline |   仓位分布: 多头=44, 空仓=46, 空头=0
# 2026-04-05 19:38:45 | INFO    | single_asset_alpha.pipeline | Step 4/5: 格式化为标准 target_position Schema...
# 2026-04-05 19:38:45 | INFO    | single_asset_alpha.pipeline |   ✅ Schema 校验通过
# 2026-04-05 19:38:45 | INFO    | single_asset_alpha.pipeline | Step 5/5: 落盘交付...
# 2026-04-05 19:38:45 | INFO    | single_asset_alpha.pipeline | ═══ 流水线完成 [SINGLE_DEMO] ═══
# 2026-04-05 19:38:45 | INFO    | single_asset_alpha.pipeline |   📄 /home/yluel/share/projects/quantsociety_backend_project/workspace_data/strategy/single_asset_alpha/single_asset_pipeline_factor_timing_v1/SINGLE_DEMO_target_position_full.parquet
# 2026-04-05 19:38:45 | INFO    | single_asset_alpha.pipeline |   📄 /home/yluel/share/projects/quantsociety_backend_project/workspace_data/strategy/single_asset_alpha/single_asset_pipeline_factor_timing_v1/SINGLE_DEMO_target_position_debounced.parquet
# 2026-04-05 19:38:45 | INFO    | single_asset_alpha.pipeline |   📄 /home/yluel/share/projects/quantsociety_backend_project/workspace_data/strategy/single_asset_alpha/single_asset_pipeline_factor_timing_v1/SINGLE_DEMO_run_meta.json
#           metric          value
# 0     trade_days      90.000000
# 1   final_equity  125728.160272
# 2   total_return       0.257282
# 3  annual_return       0.898502
# 4         sharpe      20.265722
# {'demo_root': '/home/yluel/share/projects/quantsociety_backend_project/workspace_data/demos/single_asset_pipeline_demo',
#  'configs_root': '/home/yluel/share/projects/quantsociety_backend_project/workspace_data/demos/single_asset_pipeline_demo/configs',
#  'inputs_root': '/home/yluel/share/projects/quantsociety_backend_project/workspace_data/demos/single_asset_pipeline_demo/inputs',
#  'reports_root': '/home/yluel/share/projects/quantsociety_backend_project/workspace_data/demos/single_asset_pipeline_demo/reports',
#  'kline_root': '/home/yluel/share/projects/quantsociety_backend_project/workspace_data/demos/single_asset_pipeline_demo/inputs/day_aggs_v1',
#  'market_data_path': '/home/yluel/share/projects/quantsociety_backend_project/workspace_data/demos/single_asset_pipeline_demo/inputs/mock_single_asset_ohlcv.parquet',
#  'factor_lake_root': '/home/yluel/share/projects/quantsociety_backend_project/workspace_data/factors/lake',
#  'alpha_output_root': '/home/yluel/share/projects/quantsociety_backend_project/workspace_data/strategy/single_asset_alpha/single_asset_pipeline_factor_timing_v1',
#  'target_position_path': '/home/yluel/share/projects/quantsociety_backend_project/workspace_data/strategy/single_asset_alpha/single_asset_pipeline_factor_timing_v1/SINGLE_DEMO_target_position_full.parquet',
#  'factor_frame_path': '/home/yluel/share/projects/quantsociety_backend_project/workspace_data/demos/single_asset_pipeline_demo/reports/factor_frame.parquet',
#  'backtest_output_dir': '/home/yluel/share/projects/quantsociety_backend_project/workspace_data/backtests/single_asset/single_asset_factor_timing/e2e_demo',
#  'summary_path': '/home/yluel/share/projects/quantsociety_backend_project/workspace_data/demos/single_asset_pipeline_demo/reports/pipeline_summary.json'}

# %%
factor_frame = artifacts["factor_frame"].copy()
factor_frame["timestamp"] = pd.to_datetime(factor_frame["timestamp"])
factor_frame = factor_frame.set_index("timestamp")

target_position = artifacts["target_position"].copy()
target_position["timestamp"] = pd.to_datetime(target_position["timestamp"])

returns = artifacts["returns"].copy()
returns["timestamp"] = pd.to_datetime(returns["timestamp"])

display(factor_frame.head())
display(target_position.head(12))
display(target_position["action_name"].value_counts().rename_axis("action_name").to_frame("count"))
display(returns.tail())

# %%
axes = factor_frame.plot(subplots=True, figsize=(12, 7), sharex=True)
axes[0].set_title("Materialized Factors")
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2, 1, figsize=(12, 7), sharex=True)

axes[0].plot(returns["timestamp"], returns["equity_curve"], color="#1f77b4", linewidth=2)
axes[0].set_title("Equity Curve")
axes[0].set_ylabel("equity")

axes[1].step(
    target_position["timestamp"],
    target_position["target_position"],
    where="post",
    label="target_position",
    color="#ff7f0e",
    linewidth=2,
)
axes[1].plot(
    returns["timestamp"],
    returns["realized_position"],
    label="realized_position",
    color="#2ca02c",
    linewidth=1.8,
    alpha=0.9,
)
axes[1].set_title("Target vs Realized Position")
axes[1].set_ylabel("weight")
axes[1].legend()

plt.tight_layout()
plt.show()
